# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.neighbors import KNeighborsClassifier
from matplotlib.colors import ListedColormap

# %%
#this function finds knn and plot graph
def knn_comparision(data, n_neighbors = 15):
    X=data[:,:2]
    y=data[:,2]
    # making the model
    model = KNeighborsClassifier(n_neighbors)
    model.fit(X,y)
    #grid cell size
    h = 0.02
    cmap_light = ListedColormap(['#FFAAAA', '#AAAAFF'])
    cmap_bold =  ListedColormap(['#FF0000', '#0000FF'])
    #setting meshgrid parameters
    x_min, x_max = X[:, 0].min() - 1,X[:, 0].max() + 1
    y_min, y_max = X[:, 1].min() - 1,X[:, 1].max() + 1
    #making meshgrid
    xx, yy=np.meshgrid(np.arange(x_min, x_max, h),np.arange(y_min, y_max, h))
    z = model.predict(np.c_[xx.ravel(),yy.ravel()])
    z=z.reshape(xx.shape)
    plt.figure()
    
    plt.pcolormesh(xx, yy, z, cmap = cmap_light)
    #plt scatter
    plt.scatter(X[:, 0], X[:,1], c=y,cmap = cmap_bold)
    
    #define scale
    plt.xlim(xx.min(), xx.max())
    plt.ylim(yy.min(), yy.max())
    plt.title('K Value : '+ str(n_neighbors))
    plt.show()

# %%
data = np.genfromtxt('D:/Applied AI Course/18 CLASSIFICATION AND REGRESSION MODELS K-NEAREST NEIGHBORS/data/demo_data/1.ushape.csv', delimiter=',')
knn_comparision(data, 1)
knn_comparision(data, 5)
knn_comparision(data, 15)
knn_comparision(data, 30)
knn_comparision(data, 50)

# %%
data = np.genfromtxt('D:/Applied AI Course/18 CLASSIFICATION AND REGRESSION MODELS K-NEAREST NEIGHBORS/data/demo_data/2.concerticcir1.csv', delimiter=',')
knn_comparision(data, 1)
knn_comparision(data, 5)
knn_comparision(data, 15)
knn_comparision(data, 30)
knn_comparision(data, 50)

# %%
data = np.genfromtxt('D:/Applied AI Course/18 CLASSIFICATION AND REGRESSION MODELS K-NEAREST NEIGHBORS/data/demo_data/3.concertriccir2.csv', delimiter=',')
knn_comparision(data, 1)
knn_comparision(data, 5)
knn_comparision(data, 15)
knn_comparision(data, 30)
knn_comparision(data, 50)

# %%
data = np.genfromtxt('D:/Applied AI Course/18 CLASSIFICATION AND REGRESSION MODELS K-NEAREST NEIGHBORS/data/demo_data/4.linearsep.csv', delimiter=',')
knn_comparision(data, 1)
knn_comparision(data, 5)
knn_comparision(data, 15)
knn_comparision(data, 30)
knn_comparision(data, 50)

# %%
data = np.genfromtxt('D:/Applied AI Course/18 CLASSIFICATION AND REGRESSION MODELS K-NEAREST NEIGHBORS/data/demo_data/5.outlier.csv', delimiter=',')
knn_comparision(data, 1)
knn_comparision(data, 5)
knn_comparision(data, 15)
knn_comparision(data, 30)
knn_comparision(data, 50)#for some reason it is taking too long for this model
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-8ba451bb5ca9> in <module>()
#       3 knn_comparision(data, 5)
#       4 knn_comparision(data, 15)
# ----> 5 knn_comparision(data, 30)
#       6 knn_comparision(data, 50)
#
# <ipython-input-2-74ba36b082d2> in knn_comparision(data, n_neighbors)
#      15     #making meshgrid
#      16     xx, yy=np.meshgrid(np.arange(x_min, x_max, h),np.arange(y_min, y_max, h))
# ---> 17     z = model.predict(np.c_[xx.ravel(),yy.ravel()])
#      18     z=z.reshape(xx.shape)
#      19     plt.figure()
#
# ~\Anaconda3\lib\site-packages\sklearn\neighbors\classification.py in predict(self, X)
#     143         X = check_array(X, accept_sparse='csr')
#     144
# --> 145         neigh_dist, neigh_ind = self.kneighbors(X)
#     146
#     147         classes_ = self.classes_
#
# ...

# %%
data = np.genfromtxt('D:/Applied AI Course/18 CLASSIFICATION AND REGRESSION MODELS K-NEAREST NEIGHBORS/data/demo_data/6.overlap.csv', delimiter=',')
knn_comparision(data, 1)
knn_comparision(data, 5)
knn_comparision(data, 15)
knn_comparision(data, 30)
knn_comparision(data, 50)

# %%
data = np.genfromtxt('D:/Applied AI Course/18 CLASSIFICATION AND REGRESSION MODELS K-NEAREST NEIGHBORS/data/demo_data/7.xor.csv', delimiter=',')
knn_comparision(data, 1)
knn_comparision(data, 5)
knn_comparision(data, 15)
knn_comparision(data, 30)
knn_comparision(data, 50)

# %%
data = np.genfromtxt('D:/Applied AI Course/18 CLASSIFICATION AND REGRESSION MODELS K-NEAREST NEIGHBORS/data/demo_data/8.twospirals.csv', delimiter=',')
knn_comparision(data, 1)
knn_comparision(data, 5)
knn_comparision(data, 15)
knn_comparision(data, 30)
knn_comparision(data, 50)

# %%
data = np.genfromtxt('D:/Applied AI Course/18 CLASSIFICATION AND REGRESSION MODELS K-NEAREST NEIGHBORS/data/demo_data/9.random.csv', delimiter=',')
knn_comparision(data, 1)
knn_comparision(data, 5)
knn_comparision(data, 15)
knn_comparision(data, 30)
knn_comparision(data, 50)
